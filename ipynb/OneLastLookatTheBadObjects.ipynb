# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../analysis/
# Out:
# /srv/data/home/jlee782/segmentation/analysis

# %%
from PixelEM import *
import pickle as pkl
# Out:
# /home/jlee782/.local/lib/python2.7/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
sample = "30workers_rand0"
objid = 3

# %%
gt_est_mask = pkl.load(open("../analysis/pixel_em/{}/obj{}/GTLSA_gt_est_mask_2_thresh4.pkl".format(sample,objid)))

# %%
plt.imshow(gt)

# %%
from greedyPicking import *

# %%
algo = "GTLSA"
greedy_mask = greedy(sample,objid,algo,output='mask')

# %%
def plot_img(mask):
    plt.imshow(mask)
    plt.colorbar()

# %%
sample = "30workers_rand0"
objid=7
basic_greedy_mask = greedy(sample,objid,"basic",output='mask')
worker_fraction_greedy_mask = greedy(sample,objid,"",est_type="worker_fraction",output='mask')
isoGTLSA_greedy_mask = greedy(sample,objid,"isoGTLSA",output='mask')

# %%
plot_img(basic_greedy_mask)

# %%
plot_img(worker_fraction_greedy_mask)

# %%
plot_img(isoGTLSA_greedy_mask)

# %%
sample = "30workers_rand0"
objid=28
basic_greedy_mask = greedy(sample,objid,"basic",output='mask') 
isoGTLSA_greedy_mask = greedy(sample,objid,"isoGTLSA",output='mask')

# %%
plot_img(basic_greedy_mask)

# %%
plot_img(isoGTLSA_greedy_mask)
