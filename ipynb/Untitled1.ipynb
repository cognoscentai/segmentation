# %%
cd ../analysis/
# Out:
# /Users/dorislee/Desktop/Research/seg/segmentation/analysis

# %%
# %pylab inline 
from analysis_toolbox import load_info
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
xlocs = [302, 264, 254, 250, 250, 250, 248, 247, 247, 253, 267, 275, 290, 312, 337, 353, 363, 411, 435, 449, 462, 470, 478, 480, 494, 503, 511, 529, 532, 529, 522, 521, 516, 514, 506, 495, 493, 485, 483, 468, 453, 428, 371, 358, 334]
ylocs= [124, 131, 137, 145, 152, 160, 167, 173, 188, 198, 201, 201, 205, 207, 199, 198, 211, 227, 225, 223, 224, 222, 222, 214, 223, 224, 227, 232, 223, 217, 212, 204, 192, 186, 173, 164, 158, 152, 144, 140, 129, 126, 135, 122, 126]
print mean(xlocs),mean(ylocs)
plt.plot(xlocs,ylocs)
plt.plot(mean(xlocs),mean(ylocs),'o')
# Out:
# 399.822222222 183.622222222

# %%
xlocs = [432, 437, 443, 456, 454, 474, 483, 483, 486, 480, 480, 495, 501, 504, 499, 482, 466, 465, 453, 431]
ylocs = [208, 195, 173, 168, 136, 130, 136, 142, 151, 159, 165, 174, 186, 203, 211, 208, 211, 222, 226, 216]
print mean(xlocs),mean(ylocs)
plt.plot(xlocs,ylocs)
plt.plot(mean(xlocs),mean(ylocs),'o')
# Out:
# 470.2 181.0

# %%
xlocs = [309, 286, 378, 526, 518, 405, 181, 327, 480, 480, 450, 484, 482]
ylocs = [297, 197, 347, 282, 235, 275, 313, 241, 276, 276, 304, 241, 215]
plt.plot(xlocs,ylocs)

# %%
xlocs = [286, 181, 378, 526, 518, 405, 309, 327, 480, 480, 450, 484, 482]
ylocs =  [197, 313, 347, 282, 235, 275, 297, 241, 276, 276, 304, 241, 215]
plt.plot(xlocs,ylocs)

# %%
xlocs = [313, 248, 419, 604, 564, 539, 258, 467]
ylocs = [113, 270, 320, 251, 182, 294, 175, 125]
plt.plot(xlocs,ylocs)
plt.plot(426.5,216.25,'o')

# %%
xlocs = [614, 339, 410, 586, 419, 532, 407, 494, 348, 600]
ylocs = [239, 253, 273, 189, 364, 369, 112, 151, 178, 308]
plt.plot(xlocs,ylocs)
plt.plot(426.5,216.25,'o')

# %%
xlocs = [562,420,392,572]
ylocs =[193,174,337,336]
plt.plot(xlocs,ylocs)
plt.plot(486.5,260,'o')
